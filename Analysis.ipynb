# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_3048\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("Inequality in Education.csv")

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ISO3                     195 non-null    object
#  1   Country                  195 non-null    object
#  2   HDG                      191 non-null    object
#  3   UNDP_Developing_Regions  151 non-null    object
#  4   HDI_Rank_21              191 non-null    float64
#  5   EI10                     137 non-null    float64
#  6   EI11                     150 non-null    float64
#  7   EI12                     157 non-null    float64
#  8   EI13                     165 non-null    float64
#  9   EI14                     168 non-null    float64
#  10  EI15                     168 non-null    float64
#  11  EI16                     168 non-null    float64
#  12  EI17                     168 non-null    float64
#  13  EI18                     172 non-null    float64
# ...

# %%
df['HDI_Rank_21'].value_counts()
# Out:
# HDI_Rank_21
# 91.0     4
# 140.0    3
# 35.0     3
# 80.0     3
# 63.0     3
#         ..
# 11.0     1
# 175.0    1
# 31.0     1
# 27.0     1
# 154.0    1
# Name: count, Length: 162, dtype: int64

# %%
df.columns
# Out:
# Index(['ISO3', 'Country', 'Human Development Groups',
#        'UNDP Developing Regions', 'HDI Rank (2021)',
#        'Inequality in Education (2010)', 'Inequality in Education (2011)',
#        'Inequality in Education (2012)', 'Inequality in Education (2013)',
#        'Inequality in Education (2014)', 'Inequality in Education (2015)',
#        'Inequality in Education (2016)', 'Inequality in Education (2017)',
#        'Inequality in Education (2018)', 'Inequality in Education (2019)',
#        'Inequality in Education (2020)', 'Inequality in Education (2021)'],
#       dtype='object')

# %%
df=df.rename(columns={"Human Development Groups":"HDG","UNDP Developing Regions":"UNDP_Developing_Regions",
                   "HDI Rank (2021)":"HDI_Rank_21","Inequality in Education (2010)":"EI10","Inequality in Education (2011)":"EI11","Inequality in Education (2012)":"EI12",
                  "Inequality in Education (2013)":"EI13","Inequality in Education (2014)":"EI14","Inequality in Education (2015)":"EI15",
                  "Inequality in Education (2016)":"EI16","Inequality in Education (2017)":"EI17","Inequality in Education (2018)":"EI18",
                  "Inequality in Education (2019)":"EI19","Inequality in Education (2020)":"EI20","Inequality in Education (2021)":"EI21"}).copy()

# %%
df.head()
# Out:
#   ISO3               Country        HDG UNDP_Developing_Regions  HDI_Rank_21  \
# 0  AFG           Afghanistan        Low                      SA        180.0
# 1  AGO                Angola     Medium                     SSA        148.0
# 2  ALB               Albania       High                     ECA         67.0
# 3  AND               Andorra  Very High                     NaN         40.0
# 4  ARE  United Arab Emirates  Very High                      AS         26.0
#
#         EI10       EI11       EI12       EI13       EI14       EI15  \
# 0  42.809000  44.823380  44.823380  44.823380  44.823380  45.365170
# 1        NaN        NaN        NaN        NaN        NaN  34.171440
# 2  11.900000  11.900000  11.900000  11.900000  11.900000  11.900000
# 3  15.160302  15.160302  15.160302  15.160302   9.965681  10.083815
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#         EI16       EI17       EI18       EI19       EI20       EI21
# ...

# %%
df.isnull().sum()
# checking null values in all columns
# Out:
# ISO3                        0
# Country                     0
# HDG                         4
# UNDP_Developing_Regions    44
# HDI_Rank_21                 4
# EI10                       58
# EI11                       45
# EI12                       38
# EI13                       30
# EI14                       27
# EI15                       27
# EI16                       27
# EI17                       27
# EI18                       23
# EI19                       21
# EI20                       19
# EI21                       19
# dtype: int64

# %%
df.head()
# Out:
#                 Country        HDG  HDI_Rank_21       EI10       EI11  \
# 0           Afghanistan        Low        180.0  42.809000  44.823380
# 1                Angola     Medium        148.0        NaN        NaN
# 2               Albania       High         67.0  11.900000  11.900000
